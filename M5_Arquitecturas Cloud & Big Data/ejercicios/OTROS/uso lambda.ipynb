# %%
def diHola():
  print("Hola")
diHola()
######################################
def diHolaConNombre(name):
  print("Hola " + name)

diHolaConNombre("Luis")

diHolaConNombreAnonimo = lambda name : print("Hola "+ name)
diHolaConNombreAnonimo("Luis2")
###############################################3
def diHolaConNombreYApellidos(name,surname):
  print("Hola " + name + " Apellidos: " + surname)

diHolaConNombreYApellidos("Luis", "Sastre")

(lambda name, surname : print("Hola " + name + " Apellidos: ")
