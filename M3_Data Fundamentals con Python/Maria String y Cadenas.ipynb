# %%
# %pip list #repositorio oficial de librerías de python, pip va por fuera de python, pasarlo directamente al ordenador, está preinstalado. el % indica que se lo pase directamente al ordenador sin traducir.

# %%
# !pip3 install newspaper3k #aquí estoy instalando un módulo, puedo poner % en lugar de !

# %%
# %pip list # después de hacer algo se comprueba debajo, no es necesario volver arriba , mejor hacerlo debajo

# %%
# %pip freeze

# %%
import newspaper3k

# %% [markdown]
# # ***Segundo día***
# **`_cursiva_`**
#
# [enlace](https://)

# %% [markdown]
# me meto a drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Fecha: 22/02/2023
#
#
# ```
# if condicion:
#   codigo
# elif otra_condicion:
#   codigo
# else:
#   codigo
# ```
#
#
#
# ```
# while condicion:
#   codigo
#
# ```
#
#
# ```
# def nombreFunc(variables):
#   codigo
# ```

# %%
# Objetivo: Trabajar con las cadenas de Texto

# %%
print(type(98.9))
# Out:
# <class 'float'>

# %%
variable = "Python"
print(type(variable)) # imprime tipo de variable
print(len(variable)) # imprime la longitud de la variable
print(variable.upper())# imprime la solución en mayúsculas.
# Out:
# <class 'str'>
# 6
# PYTHON

# %%
#para e en la variable 'python'  
cont = 0
for letra in 'python':
  print('El valor de e es ', letra)
  cont = cont +1
  print(cont)

print('al final el valor de e es', e)

# %%
for i in range(len(variable)): #variable no itera por que es str, len(variable) tampoco porque necesita varios valores en un intervalo range(len(variable))
  print(f'el valor de {variable[i]} es {i}')

print('-'*30)

for i in range(len(variable)): #para deletrear al revés
  print(variable[-i-1])

#print(list(enumerate(variable))) #así también se deletrea

print('-'*30)

for i, thing in enumerate(variable): #esto lo usa la gente high level
  print(f'valor {thing} \t posición {i}')

# %%
var = input('he escrito:   ')

for rastreo in range(len(var)):
  print(f'el valor de la {var[rastreo]} es {rastreo} ')

#print(list(enumerate(var))) # otra forma de escribir lo mismo

for i, rastreo in enumerate(var):
  print(f'el valor de la {rastreo} es {i} ')
# Out:
# he escrito:   poij
# el valor de la p es 0
# el valor de la o es 1
# el valor de la i es 2
# el valor de la j es 3
# el valor de la p es 0
# el valor de la o es 1
# el valor de la i es 2
# el valor de la j es 3

# %%
for letra in variable: # le digo que me imprima cada caracter de la variable.
  print(letra)# como python es capaz de recorrer las letras en cada vez que la recorre imprime un carcater.
# Out:
# P
# y
# t
# h
# o
# n

# %%
for chiripitiflautico in "Hola que tal estás": # para cada letra en hola que tal estás imprime la letra, imprime cada letra en una línea
  print(chiripitiflautico)
# Out:
# H
# o
# l
# a
#
# q
# u
# e
#
# t
# a
# l
#
# e
# s
# t
# á
# s

# %%
print(0, 'p')
print(1, 'y')
print(2, 't')
print(3, 'h')
print(4, 'o')
print(5, 'n')
contador=0
contador = contador+1
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %%
''''
contador = 0
for letra in "Python":
  print(contador, letra)
  contador = contador+1 #j+= 1 
'''

print(contador, letra)#esto hace que repita la última letra y el contador.

#Mejor usar enumerate para ver el contador
for i, thing in enumerate(variable): #esto lo usa la gente high level
  print(f'valor {thing} \t posición {i}')
# Out:
# 0 P
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n
# 6 n

# %%
variable = "IbonReinoso D"
# Pregunto por el tamaño
print(len(variable))

print(variable[4])
print(variable[-1])#si yo quiero llegar a la última posición de algo [-1]
# Out:
# 13
# R
# D

# %%
print(variable[:])  #variable[inicio:fin:paso]  corta antes de lo que llamamos fin. paso es lo que salta
print(variable[:3]) #
print(variable[3:]) 
print(variable[2:-2]) 
print(variable[2:-2:3]) 
print(variable[::-2]) #variable[inicio:fin:paso]
print(variable[::2]) #empieza en el 0 acaba en el final y vas de 2 en 2 (trae las posiciones pares)
print(variable[1::2]) # devolvería los impares
print(variable[::-1]) #recorre la palabra al revés
# Out:
# IbonReinoso D
# Ibo
# nReinoso D
# onReinoso
# oeo
# IoRiooD
# bnens
# D osonieRnobI

# %%
print(variable[::-2])
# Out:
# DooiRoI

# %% [markdown]
# Hasta aqui las rodajas (slices)

# %%
'HASDFVAEBAasas98879aGV'.lower()# lower a minúsculas
# Out:
# 'hasdfvaebaasas98879agv'

# %%
variableMala = "AL3$4NDR0NP3%mDigu3R0,es"

print(variableMala.split('R')) # le estoy diciendo que me separe por la letra R, separa la variable de texto con el caracter que le he indicado, la variable por el que separa lo anula y desaparece
# hace una lista con variables de texto. no hay espacios por lo que no puedo dividir por espacios.
print(type(variableMala.split(',')))# nos devuelve el tipo de variable que es, como lleva corchetes es una lista. 
# input siempre devuelve variable tipo texto y split siempre devuelve variable tipo lista.
# Out:
# ['AL3$4ND', '0NP3%mDigu3', '0,es']
# <class 'list'>

# %%
variableBuena = variableMala.split('R') #varaiableBuena también será una lista, 
print(variableBuena)
print(variableBuena[0])
variableBuena[1] = variableBuena[1].lower() # en el índice 1 ponme lo mismo pero en minúsculas, estoy sustituyendo, en las listas puedo, si fuese una tupla no podría.
variableBuena[0] = 'Alejandro'# en la posición cero de la variable Buena tengo un texto que es Alejandro. si pongo un número que no empiece por cero!!
print(variableBuena)
# Out:
# ['AL3$4ND', '0NP3%mDigu3', '0,es']
# AL3$4ND
# ['Alejandro', '0np3%mdigu3', '0,es']

# %%
a = '898'
a = int(a) 
print(a)
# Out:
# 898

# %%
variableMala = "AL3R$4NDR0NP3%mDigu3r0.es"

# variableBuena = variable.replace('#', 'o') reemplaza lo que yo le diga. 
variableBuena = variableMala.replace('%', 'r') # quiero reemplazar el % por una r.
print(variableBuena)

variableBuena = variableBuena.replace('3', 'e', 2)# reemplaza el 3 por una e, y el 2 indica el número de veces que lo va a reemplazar, el tercer 3 que tengo lo deja.
# el valor por defecto de la función replace es que lo reemplaza en todos, salvo que le indique una cantidad.
variableBuena = variableBuena.replace('m', '')

print(variableBuena)
# Out:
# AL3R$4NDR0NP3rmDigu3r0.es
# ALeR$4NDR0NPerDigu3r0.es

# %%
# variableBuena[::-2] #Le damos la vuelta :D
# variableBuena.lower() #LowerCase
variableBuena = variableBuena.lower() #UpperCase
print(variableBuena)
# Out:
# aler$4ndr0nperdigu3r0.es

# %% [markdown]
# ## métodos para strings
#
# https://www.w3schools.com/python/python_ref_string.asp

# %%
tierra = "La;T1eRR@#Es#Red0nD@?" #.capitalize() pone en mayuscula la primera letra .title() pa toda la primera letra
tierra = '¿' +  tierra.replace(';', ' ').replace('1', 'i').replace('@', 'a').replace('#', ' ').replace('0', 'o').lower().capitalize().replace('t', 'T') 
print(tierra)

# %%
#Mi manera de escribirlo:
tierra = "La;T1eRR@#Es#Red0nD@?"
tierra = tierra.replace(';',' ')
tierra = tierra.replace('1','i')
tierra = tierra.replace('@','a')
tierra = tierra.replace('#',' ')
tierra = tierra.replace('0','o')
tierra = tierra.lower()
tierra = tierra.replace('l','L')
tierra = tierra.replace('t','T')
tierra='¿'+ tierra + ' Según desde donde se mire!'
print(tierra)

'''
# otra forma de escribirlo! 
tierra = "La;T1eRR@#Es#Red0nD@?"
tierra = tierra.replace(';',' ') .replace('1','i') .replace('@','a').replace('#',' ').replace('0','o').lower()
tierra = tierra.replace('l','L').replace('t','T')
tierra='¿'+ tierra + ' Según desde donde se mire!'
print(tierra)'''
# Out:
# ¿La Tierra es redonda? Según desde donde se mire!

# %%
tierra = "La;T1eRR@#Es#Red0nD@?"
tierra = tierra.replace(";"," ").lower()
print(tierra)
tierra = tierra.replace("1","i")
tierra = tierra.replace("@","a")
tierra = tierra.replace("#"," ")
tierra = tierra.replace("0", "o")#.replace("?",".")
tierra = '¿'+tierra
#tierra = tierra.replace("l","¿L", 1)
tierra = tierra.replace("t","T")

print(tierra)
# Out:
# la t1err@#es#red0nd@?
# ¿la Tierra es redonda?

# %%
#tierra = '¿'+tierra+'?'

interrogacion1="¿"
interrogacion2="?"
print(tierra)

# %%
rawData = "La;T1eRR@#Es#Red0nD@?"
rwaData = rawData.replace("@", 'a' )
rwaData = rwaData.replace(";", ' ' )
rwaData = rwaData.replace("1", 'i' )
rwaData = rwaData.replace("#", ' ' ).replace("0", 'o' )
rwaData = rwaData.lower()
print(rwaData)

rwaData = rwaData.replace("l", 'L' )
rwaData = rwaData.replace("t", 'T' )
print(rwaData)
# Out:
# la tierra es redonda?
# La Tierra es redonda?

# %%
#Frase Origen
rawData = "La;T1eRR@#Es#red0nD@#?"
print('primer res', rawData)
goodData = rawData.lower()
print(goodData)
goodData = goodData.replace('#',' ', 2)
goodData = goodData.replace('#','')
print('mirad este de aqui', goodData)
goodData = goodData.replace('@','a')
goodData = goodData.replace('1','i')
goodData = goodData.replace(';',' ').replace('0','o')
# goodData = goodData.title()
print('Al final del todo',goodData)


goodData = '¿'+goodData
print('antes de capit', goodData)
goodData = goodData.capitalize()

print('Al finalFINAL del todo',goodData)
# Out:
# primer res La;T1eRR@#Es#red0nD@#?
# la;t1err@#es#red0nd@#?
# mirad este de aqui la;t1err@ es red0nd@?
# Al final del todo la tierra es redonda?
# antes de capit ¿la tierra es redonda?
# Al finalFINAL del todo ¿la tierra es redonda?

# %%
goodData = '¿la tierra es redonda?'.title() # lo pone en formato título.

# replace('l', 'L') minus por mayus
# .capitalize() Poner en mayúscula del primer caracter.sea el que sea, por lo que si el primer caracter es una interrogación no funciona.
print(goodData)

# %%
var = 'Hola'
var[0]='C'
#var = 'C' + var[1:] cambio la variable 0 que es la h por una c y le cambio a la palabra de la variable var todo menos la primera c
print(var)

# %%
var = 'Hola'
var = 'Tr' + var[1:]
print(var)
# Out:
# Trola

# %%
tup1 = (1,2,3)
tup2 = (1,3,2)
print(tup1[2])
#tup1[0] = 87 las tuplas no se pueden modificar, para eso necesitaríamos que fuese una lista.
# Out:
# 3

# %%
tup1 = (1,2,3)
tup2 = (1,3,2)
tup1 == tup2
# Out:
# False

# %%
dicc1 = {'Juan': 9, 'Javier':8.7}
dicc2 = {'Javier':8.7, 'Juan': 9}
print(dicc1['Juan'], dicc2['Juan'])
# Out:
# 9 9

# %%
lista = "[1,m2],3,4".split(',')
print(lista, type(lista))
lista = "1,2,3,4".split(',')
print(lista, type(lista))
# Out:
# ['[1', 'm2]', '3', '4'] <class 'list'>
# ['1', '2', '3', '4'] <class 'list'>

# %%
lista = "[1,m2],3,4".split(',')
print(lista, type(lista), len(lista))
print(lista[0])
lista[0] = lista[0].replace('[', '')
lista[1] = lista[1].replace(']', '')
print(lista)
subListaFinal = [ lista[0], lista[1] ]
listaFinal = [subListaFinal, lista[2], lista[-1]]

print(listaFinal, len(listaFinal))

listaFinal[1] = int(listaFinal[1])
listaFinal[2] = int(listaFinal[2])
listaFinal[0][0] = int(listaFinal[0][0])

print(listaFinal)

# %%
lista = "[1,m2],3,4".split(',') #.split() es un método para strings
print(lista, type(lista), f'número de elementos {len(lista)}')
lista[0] = lista[0].replace('[', '') #se indica el elemento dónde esta el str, sino no funciona sobre la lista
lista[1] = lista[1].replace(']', '')
#lista = "1,2,3,4".split(',')
print(lista, type(lista))

#si yo ahora quiero meter ahí una sublista como en el principio hago esto
listaFinal1 = [[lista[0], lista[1]], lista[2], lista[3]]
listaFinal = [lista[0], lista[1], lista[2], lista[3]]

print(listaFinal1); print(listaFinal)

def is_number(s):  #defino la función prueba de número
    try:
        int(s)
        return True
    except ValueError:
        return False

listaexpresion = [int(x) if is_number(x) == True else x for i, x in enumerate(listaFinal)] #sintaxis chachi :)
print(listaexpresion)

listanueva = [] #sintaxis más comprensible para María... por ahora
for i, x in enumerate(listaFinal):
  if is_number(x) == True:
    listanueva.append(int(x))
  else:
    listanueva.append(x)

print(listanueva)

# %%
lista = "1,2,3,4;1,2,3,4".split(';')
print(lista, type(lista))

lista[0] = lista[0].split(',')
#lista = ['1', '2', '3', '4']
print(lista, type(lista))

# %%
#goodData[1] = goodData[1].upper()
goodData = '¿La Tierra Es Redonda?'
print(goodData, type(goodData))
Data2 = goodData.split()# ojo con este split es INTERESANTEEEE!!
print(Data2, type(Data2))
#Frase final
# Out:
# ¿La Tierra Es Redonda? <class 'str'>
# ['¿La', 'Tierra', 'Es', 'Redonda?'] <class 'list'>

# %%
'Diccionario'.split()
# Out:
# ['Diccionario']

# %%
lista = [1, '2', 3, "aaaaa", "bbbb"]
print('esto es la longitud: ',len(lista))
# lista2 = lista.upper() lista no tiene funcion upper 
print(lista)
print(lista[3])
# Out:
# esto es la longitud:  5
# [1, '2', 3, 'aaaaa', 'bbbb']
# aaaaa

# %%
lista[1] = int(lista[1])
print(lista)

# %%
lista[0] = 'Mario'
lista[4] = lista[4].upper()
print(lista)

# %%
# funciones asociadas a variables no funcionan con otros tipos de variables
lista.upper()

# %%
for item in lista:
  print('ahora vamos por el elemento', item)
# Out:
# ahora vamos por el elemento 1
# ahora vamos por el elemento 2
# ahora vamos por el elemento 3
# ahora vamos por el elemento aaaaa
# ahora vamos por el elemento bbbb

# %% [markdown]
# ## Ejercicio Tratamiento de texto

# %%
lista = [1,2,3,'Hola', 3,4,5, 'Hola', 2]
print('Me traigo la primera posicion de Hola')
indice = lista.index('Hola')
print(indice)
print('la lista desde la posicion de Hola\n', lista[indice:])
print('la lista desde la posicion siguiente a la de Hola\n', lista[indice+1:])

sublista =lista[indice+1:]
sublista.index('Hola')
# Out:
# Me traigo la primera posicion de Hola
# 3
# la lista desde la posicion de Hola
#  ['Hola', 3, 4, 5, 'Hola', 2]
# la lista desde la posicion siguiente a la de Hola
#  [3, 4, 5, 'Hola', 2]
# 3

# %%
float('98.9')

# %%
# Fecha: 13/12/2022
# Autor: José Luis Martínez
# Objetivo: extraer datos de texto en variables y limpiarlos. 
# Si las variables son listas debemos respetarlas

rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"
solucion = [6, 1, 'Chicken Crispy Tacos', ['Roasted Chilli Corn Salsa', ['Fajita Vegetables', 'Rice', 'Black Beans', 'Cheese', 'Sour Cream']], 8.75]
print(rawData[1])
print(solucion[1])
rawData2 = "14, 1, Carnitas Burrito,[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans; Rice; Sour Cream; Lettuce]], $8.99"
# Out:
# ,
# 1

# %%
rawData2 =rawData.split(',')
rawData2[0] = int(rawData2[0])
print(rawData2[4])
print(rawData2[4].replace(';', 'hola'))
print(rawData2[4].split(';'))
# Out:
#  [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]]
#  [Fajita Vegetableshola Ricehola Black Beanshola Cheesehola Sour Cream]]
# [' [Fajita Vegetables', ' Rice', ' Black Beans', ' Cheese', ' Sour Cream]]']

# %% [markdown]
# ### Soluciones extra

# %% [markdown]
# RESOLUCIÓN ARTURO

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75" # variable a convertir
solucion = [6, 1, 'Chicken Crispy Tacos', ['Roasted Chilli Corn Salsa', ['Fajita Vegetables', 'Rice', 'Black Beans', 'Cheese', 'Sour Cream']], 8.75]
rd = rawData.replace('0', 'o').replace(';', ',').replace('$', '').replace('[', '').replace(']', '').lower().title().split(',') # limpiamos caracteres raros
rd = [x.strip() for x in rd] # limpiamos el primer y último espacio en cada str de rd
print(rd) # veo como va la cosa en mi lista despues de limpiarla, que ya hemos hecho bastante
rd[-1]= float(rd[-1]); rd[0] = int(rd[0]); rd[1] = int(rd[1]) # cambio los str a números enteros (6 y 1) y decimal (8.75)

sublista_1 = [rd[i] for i in range(4,9)] # creamos la primera sublista
sublista_2 = [rd[3], sublista_1] # creamos la segunda sublista
listaFin = [rd[0], rd[1], rd[2], sublista_2, rd[-1]] # montamos todo bonito
print(listaFin) # a ver que tal...
listaFin == solucion #Es EXACTAMENTE lo mismo ????

# %% [markdown]
# CODIGO DEL BUCLE PARA QUITAR LOS ESPACIOS CON STRIP()

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75" # variable a convertir
rd = rawData.replace('0', 'o').replace(';', ',').replace('$', '').replace('[', '').replace(']', '').lower().title().split(',') # limpiamos caracteres raros
print(rd)

rnueva = []
for x in rd:
  x = x.strip()
  rnueva.append(x)

print(rnueva) # veo como va la cosa en mi lista despues de limpiarla, que ya hemos hecho bastante

# %%
x = [546, 65253, 76, 9, 62]
print([float(x) for i, x in enumerate(x)])

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"
semiRawData1 = rawData.split(',')       # Separamos los datos
sublist1 = semiRawData1[4].split(';')   # creamos sublista interiro y separamos los datos
contador = 0                            # eliminamos primer espacio y corchetes para sublista interior [a,b,[sublist2,[sublist1]]]
for item in sublist1:
  sublist1[contador] =sublist1[contador].replace('[','')
  sublist1[contador] =sublist1[contador].replace(']','')
  sublist1[contador] =sublist1[contador].replace(' ','',1)
  contador = contador +1
sublist2 =[semiRawData1[3].replace('0','o'), sublist1]    #creamos sublista exterior y le cambiamos 0, LLI, y corchetes
sublist2[0] =sublist2[0].replace('[','')
sublist2[0] =sublist2[0].replace('LLI','lli')
finalData=[int(semiRawData1[0]), int(semiRawData1[1]), semiRawData1[2].replace(' ','',1), sublist2, semiRawData1[5].replace(' ','')]  #lista final, asignando integer a los numeros y la listas
print('INICIO:  ',rawData)
print('FINAL:  ',finalData)
# Out:
# INICIO:   6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75
# FINAL:   [6, 1, 'Chicken Crispy Tacos', ['Roasted Chilli Corn Salsa', ['Fajita Vegetables', 'Rice', 'Black Beans', 'Cheese', 'Sour Cream']], '$8.75']

# %%
rawData2 = "14, 1, Carnitas Burrito,[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans; Rice; Sour Cream; Lettuce]], $8.99"
SemiRawData2 = rawData2.split(',')      # Separamos los datos
sublist3= SemiRawData2[5].split(';')    # FINAL=
contador2 = 0                            # 
for item in sublist3:
  sublist3[contador2] =sublist3[contador2].replace('[','')
  sublist3[contador2] =sublist3[contador2].replace(']','')
  sublist3[contador2] =sublist3[contador2].replace(' ','',1)
  contador2=contador2+1
SemiRawData3 = SemiRawData2[3].split('-')
sublista4 = [SemiRawData3[0].replace('[',''),SemiRawData3[1],SemiRawData2[4].replace(' ','',1)]
sublista5 = [sublista4,sublist3]
finalData2= [int(SemiRawData2[0]),int(SemiRawData2[1]), SemiRawData2[2].replace(' ','',1), sublista5, SemiRawData2[6].replace(' ','')]
print('INICIO:  ',rawData2)
print('FINAL:  ', finalData2)
# Out:
# INICIO:   14, 1, Carnitas Burrito,[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans; Rice; Sour Cream; Lettuce]], $8.99
# FINAL:   [14, 1, 'Carnitas Burrito', [['Tomatillo', 'Green Chili Salsa (Medium)', 'Roasted Chili Corn Salsa (Medium)]'], ['Black Beans', 'Rice', 'Sour Cream', 'Lettuce']], '$8.99']

# %%
rawData2 =rawData.split(',')
rawData2[0] = int(rawData2[0])
print(rawData2[4])
print(rawData2[4].replace(';', 'hola'))
print(rawData2[4].split(';'))
# Out:
#  [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]]
#  [Fajita Vegetableshola Ricehola Black Beanshola Cheesehola Sour Cream]]
# [' [Fajita Vegetables', ' Rice', ' Black Beans', ' Cheese', ' Sour Cream]]']

# %%
'''
  Ejercicio de tratamiento de texto
  Limpiar Tabla - Traducir rawData a una lista donde Python sepa qué tipo de datos incluye, correctamente.
  Usar todas las funciones de string disponibles.
  Objetivo: extraer datos de texto en variables y limpiarlos. 
  Si las variables son listas debemos respetarlas
'''

import re                     # importar expresiones regulares
pattern= r'[0-9]*\.[0-9]*'    # patrón (básico) para hallar números decimales

# LIMPIAR rawData
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"

# modifico separadores para diferenciar elementos de la lista correctamente, dividiendo $8,75
data = rawData.replace(',[',', [').replace('Salsa,','Salsa|').replace('$8.75','$, 8.75')
print(data)
# Out:
# 6, 1, Chicken Crispy Tacos, [R0asted ChiLLI C0rn Salsa| [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $, 8.75

# %%
# Creo primera lista
data = data.split(", ")
print(data)
# Out:
# ['6', '1', 'Chicken Crispy Tacos', '[R0asted ChiLLI C0rn Salsa| [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]]', '$', '8.75']

# %%
# data[0] = int(data[0])  
# data[1] = int(data[1])  
# data[-1] = float(data[-1])  

# Convierto a números enteros y floats usando regex
cont=0
for n in data:
  stro = data[cont]

  if stro.isnumeric():
    stro = int(stro)
  elif re.fullmatch(pattern, stro): # Hallar decimal
    stro = float(stro)
  
  data[cont] = stro  
  cont = cont+1

# %%
# A por la segunda lista - eliminamos corchetes y creamos lista
lista2 = data[3].replace('[','',1).replace(']]',']')
data[3] = lista2.split('|')
print(data[3])
# Out:
# ['R0asted ChiLLI C0rn Salsa', ' [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]']

# %%
# Limpiamos
data[3][0] = data[3][0].replace('0','o').title()
#data[3][0] = chilly
print(data[3])
# Out:
# ['Roasted Chilli Corn Salsa', ' [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]']

# %%
# A por la tercera lista - Eliminamos corchetes y creamos lista
fajita = data[3][1].replace(' [','').replace(']','').replace('; ',';').split(';')
data[3][1] = fajita
print(data[3])
# Out:
# ['Roasted Chilli Corn Salsa', ['Fajita Vegetables', 'Rice', 'Black Beans', 'Cheese', 'Sour Cream']]

# %%
# Convertimos dos últimos datos en diccionario de precios
precios = {data[-2]: data[-1]}
data[-2] = precios
data.pop(-1)       # BORRAMOS último elemento (8.75)

# SOLUCIÓN rawData !!!
print('\nSOLUCION RAWDATA')
print(data)
# Out:
# SOLUCION RAWDATA
# [6, 1, 'Chicken Crispy Tacos', ['Roasted Chilli Corn Salsa', ['Fajita Vegetables', 'Rice', 'Black Beans', 'Cheese', 'Sour Cream']], {'$': 8.75}]

# %%
# LIMPIAR rawData2
rawData2 = "14, 1, Carnitas Burrito,[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans; Rice; Sour Cream; Lettuce]], $8.99"

# modifico separadores para diferenciar elementos de la lista correctamente, divido $8,99
data2 = rawData2.replace(',[',', [').replace('), ',')|').replace('], [',']![').replace('$8.99','$, 8.99').replace(', ',',')

# Creo primera lista
data2 = data2.split(",")

# Convierto a números enteros y floats usando regex
cont2=0
for p in data2:
  str = data2[cont2]

  if str.isnumeric():
    str = int(str)
  elif re.fullmatch(pattern, str): # Hallar decimal
    str = float(str)
  
  data2[cont2] = str  
  cont2 = cont2+1

# A por la segunda lista - eliminamos corchetes y creamos lista
lista2 = data2[3].replace('[','').replace(']','')
data2[3] = lista2.split('!')

# A por la tercera lista - split por |
lista3 = data2[3][0].split('|')
data2[3][0] = lista3

# A por la cuarta lista - Limpiamos espacios y split por !
lista4 = data2[3][1].replace('; ',';').split(';')
data2[3][1] = lista4

# Convertimos dos últimos datos en diccionario de precios
precios2 = {data2[-2]: data2[-1]}
data2[-2] = precios2
data2.pop(-1)       # BORRAMOS último elemento (8.75)

# SOLUCIÓN rawData2 !!!
print('\nSOLUCION RAWDATA2')
print(data2)
# Out:
# SOLUCION RAWDATA2
# [14, 1, 'Carnitas Burrito', [['Tomatillo-Green Chili Salsa (Medium)', 'Roasted Chili Corn Salsa (Medium)'], ['Black Beans', 'Rice', 'Sour Cream', 'Lettuce']], {'$': 8.99}]

# %% [markdown]
# Alba

# %%
'''
  Autor: Alba R. Diez
  Fecha: 08-Feb-2023
  Objetivo: extraer datos de texto en variables y limpiarlos
  '''
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"

rawData = rawData.replace('$','') #eliminar el $
rawData = rawData.replace(', ',',')
print('hoooola', rawData)
rawData = rawData.replace(" '","'")
rawData = rawData.replace('; ',';')
rawData = rawData.replace('Salsa,','Salsa;')

print('rawData',rawData,'\n')

rawData_list1 = rawData.split(',') #ahora es una lista

print('rawDatamod',rawData_list1,'\n')

rawData_list1[0] = int(rawData_list1[0])
rawData_list1[1] = int(rawData_list1[1])
rawData_list1[4] = float(rawData_list1[4])

print('list1 con numeros arreglados',rawData_list1,'\n')

rawData_list2 = rawData_list1.pop(3)
print('list1 sin lista 2',rawData_list1,'\n') #final
print('list2_final',rawData_list2,'\n')

rawData_list2 = rawData_list2.replace(';[',',[')
rawData_list2 = rawData_list2.split(',')

rawData_list2[0] = 'Roasted Chilli Corn Salsa'
print('la segunda lista que tiene una lista\n',rawData_list2 )
rawData_list3 = rawData_list2.pop(1)
#rawData_list3 = rawData_list3.split(';') 
print('al comienzo', rawData_list3)
rawData_list3 = rawData_list3.replace('[','')
print('quitar [', rawData_list3)
rawData_list3 = rawData_list3.replace(']','')
print('quitar ]', rawData_list3)
rawData_list3 = rawData_list3.split(';')
print('al hacer split', rawData_list3)

print('list2 sin lista 3',rawData_list2,'\n')
print('list3_final',rawData_list3,'\n')

rawData_list2.insert(1,rawData_list3)
rawData_list1.insert(3,rawData_list2)
print('list2+3',rawData_list2,'\n')
print('Final',rawData_list1,'\n')
# Out:
# hoooola 6,1,Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa,[Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]],8.75
# rawData 6,1,Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa;[Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]],8.75
#
# rawDatamod ['6', '1', 'Chicken Crispy Tacos', '[R0asted ChiLLI C0rn Salsa;[Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]', '8.75']
#
# list1 con numeros arreglados [6, 1, 'Chicken Crispy Tacos', '[R0asted ChiLLI C0rn Salsa;[Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]', 8.75]
#
# list1 sin lista 2 [6, 1, 'Chicken Crispy Tacos', 8.75]
#
# list2_final [R0asted ChiLLI C0rn Salsa;[Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]
#
# la segunda lista que tiene una lista
#  ['Roasted Chilli Corn Salsa', '[Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]']
# al comienzo [Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]
# quitar [ Fajita Vegetables;Rice;Black Beans;Cheese;Sour Cream]]
# ...

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"
rawData= rawData.replace("0","o")
rawData = rawData.replace(" ","")
solucion = rawData.split(",")
print(solucion)

solucion[0] = int(solucion[0]) 
result=type(solucion[0])
print("la posicion 0 es de tipo", result )

solucion[1] = int(solucion[1]) 
result=type(solucion[1])
print("la posicion 1 es de tipo", result )

result=type(solucion[2])
print("la posicion 2 es de tipo", result )

result=type(solucion[3])
print("la posicion 3 es de tipo", result, solucion[3] )

print("la posicion 4 es de tipo", result , solucion[4])

solucion[4]=(solucion[4].split(";"))
result=type(solucion[4])
print("la posicion 4 es de tipo", result , solucion[4])

solucion[5]=solucion[5].replace("$","")
solucion[5]=float(solucion[5])

solucion[3] = solucion[3].strip()


for item in solucion:
    print(item)

print(solucion)
# Out:
# ['6', '1', 'ChickenCrispyTacos', '[RoastedChiLLICornSalsa', '[FajitaVegetables;Rice;BlackBeans;Cheese;SourCream]]', '$8.75']
# la posicion 0 es de tipo <class 'int'>
# la posicion 1 es de tipo <class 'int'>
# la posicion 2 es de tipo <class 'str'>
# la posicion 3 es de tipo <class 'str'> [RoastedChiLLICornSalsa
# la posicion 4 es de tipo <class 'str'> [FajitaVegetables;Rice;BlackBeans;Cheese;SourCream]]
# la posicion 4 es de tipo <class 'list'> ['[FajitaVegetables', 'Rice', 'BlackBeans', 'Cheese', 'SourCream]]']
# 6
# 1
# ChickenCrispyTacos
# [RoastedChiLLICornSalsa
# ['[FajitaVegetables', 'Rice', 'BlackBeans', 'Cheese', 'SourCream]]']
# 8.75
# [6, 1, 'ChickenCrispyTacos', '[RoastedChiLLICornSalsa', ['[FajitaVegetables', 'Rice', 'BlackBeans', 'Cheese', 'SourCream]]'], 8.75]

# %%
print(solucion2[4])
print(solucion[4])
lista2 = [solucion[3], solucion[4]]
apanyo = [solucion[0], 
          solucion[1], 
          solucion[2],
          lista2, 
          solucion[5]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0b226d09d5b9> in <module>
# ----> 1 print(solucion2[4])
#       2 print(solucion[4])
#       3 lista2 = [solucion[3], solucion[4]]
#       4 apanyo = [solucion[0],
#       5           solucion[1],
#
# NameError: name 'solucion2' is not defined

# %%
print(apanyo[3])
print(solucion2[3])

# %% [markdown]
# ### Resolución del Ejercicio

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"
print('Este es el tipo de dato de rawData', type(rawData))

# %%
print('Primer elemento de rawData', rawData[0], type(rawData[0]))
print('Segundo elemento de rawData', rawData[1], type(rawData[1]))

# %%
# convertimos a lista
listData = rawData.split(',') # aqui uso split para separar por las comas
print('Este es el tipo de dato de listData', type(listData))
print(listData)

# %%
print('Primer elemento de listData', listData[0], type(listData[0]))
print('Segundo elemento de listData', listData[1], type(listData[1]))

# %%
print('longitud de la lista', len(listData))# longitud de listData

for item in listData:
  print(item)

# %%
int('90989')

# %%
listData[0] = int(listData[0]) # cojo el primer elemento y lo paso por int() para convertir a num
listData[1] = int(listData[1])
print('Después de modificar los 2 primeros nums \n', listData)
print(type(listData[0]))

# %%
print(listData[-1], type(listData[-1]), listData[-1].replace('$', ''))

print(type(listData[-1].replace('$', '')))

# %%
#listData[-1] = listData[-1].replace('$', '')
#listData[-1] = float(listData[-1])

listData[-1] = float( listData[-1].replace('$', '') )

print('Después de modificar los 3 nums\n', listData)

# %%
print(listData[2]) # --> ' Chicken Crispy Tacos'
print(listData[2].replace(' ', '')) # opción 1: replace con el count ese
print(listData[2].replace(' ', '', 1)) # opción 1: replace con el count ese

# %%
print(listData[2][0])
print(listData[2][1])

print(listData[2][1:]) # ignoramos el primer espacio

# %%
'     Chicken Crispy Tacos               '.strip()

listData[2].strip()

# %%
listData[2] = listData[2].strip()
print('modificado el 3 elemento', listData)

# %%
print(listData[3])
print(type(listData[3]))

listData[3] = listData[3].replace('0', 'o')
listData[3] = listData[3].replace('L', 'l')
listData[3] = listData[3].replace('I', 'i')
listData[3] = listData[3].replace('[', '')

print('modificado el 4 elemento', listData)

# Esto es igual a lo que vimos
a = '98'
a = int(a)

tierra = 'La#Tierra'
tierra = tierra.replace('#', '')

# %%
print(listData[4])
print(listData[4][0])
print(listData[4][2:-2])
listData[4] = listData[4][2:-2]
listData[4] = listData[4].split(';')
print('lista\n', listData)

# %%
print(listData[4])
print(type(listData[4]))

# %%
listaIng = listData[4]

print(listaIng)
listaIng[0] = listaIng[0].strip()
listaIng[1] = listaIng[1].strip()
listaIng[2] = listaIng[2].strip()
listaIng[3] = listaIng[3].strip()
listaIng[4] = listaIng[4].strip()
print(listaIng)

# %%
listData

# %%
listaDataFinal = [listData[0], 
                  listData[1], 
                  listData[2], 
                  [listData[3], listaIng], 
                  listData[-1]]

print('Este es el resultado final\n', listaDataFinal)

print(listaDataFinal[3][0])
print(type(listaDataFinal[3]))

# %%
listaDataFinal[3][1]

# %% [markdown]
# Aquí tenemos una resolución más sencilla y menos explicada

# %%
raw_data = "6, 1, Chicken Crispy Tacos,[R0asted ChLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"

transformed_data = raw_data.split(',')

num1 = transformed_data[0] #Ok
num2 = transformed_data[1] #Ok
num2 = num2[1:]

recipie = transformed_data[2].lower()

sauce = transformed_data[3].lower()
sauce = sauce.replace('0','o')
sauce = sauce[1:]

amount_of_sauce = transformed_data[4]
amount_of_sauce = len(amount_of_sauce.split(';'))

price = transformed_data[5]
price = float(price[2:])
print(price,type(price))

output = [num1, num2, recipie, sauce, amount_of_sauce, price]
print(output)

# 6, 1, chicken crispy tacos, roasted chilli corn salsa, 5 (int) , 8.75 (float)

# %% [markdown]
# ### Hay muchos espacios, ¿no?

# %%
opc2 = " Hola, que    tal.\thola     \n\n\n\n"
opc3 = opc2.strip() # elimina los espacios iniciales y finales de una cadena de caracteres
print('opc2',opc2, opc3)
print([opc2, opc3], ' \nHola, que   tal.           \n')

# %%
rawData = "6, 1, Chicken Crispy Tacos,[R0asted ChiLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"

rawData = rawData.split(',')
rawData[0] = int(rawData[0])
rawData[1] = int(rawData[1])
print(rawData)
print(rawData[2][1:])
# rawData[2] = rawData[2][1:]
# rawData[2] = rawData[2].strip()

rawData[2] = rawData[2].replace(' ', '', 1)


nuevaLista = rawData[4].split(';')
nuevaLista[-1] = nuevaLista[-1].replace(']', '')

listaFinal = [rawData[3], nuevaLista]
listaFinal[1]

# %% [markdown]
# ### Cómo hacer mejor lo de cambiar elemento a elemento

# %%
lista = ['aaaaa', 'bbbb', 'ceh']

for item in lista:
  print(item.upper())
  item = item.upper()

print(lista)
lista[0] = lista[0].upper()
lista[1] = lista[1].upper()
lista[2] = lista[2].upper()

# %%
raw_data = "6, 1, Chicken Crispy Tacos,[R0asted ChLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"

transformed_data = raw_data.split(',')

num1 = int(transformed_data[0]) #Ok
num2 = transformed_data[1] #Ok
num2 = num2[1:]

recipie = transformed_data[2].lower()
print(recipie)
sauce = transformed_data[3].lower()
sauce = sauce.replace('0','o')
print(sauce)
sauce = sauce[1:]

amount_of_sauce = transformed_data[4]
amount_of_sauce = len(amount_of_sauce.split(';'))
print(amount_of_sauce)


listaFinal = transformed_data[4].replace(']', '').replace('[', '').split(';')
print('lista sin modificar', listaFinal)
# range(0, len(iLis))

# listaFinal[0] = listaFinal[0].strip()
# listaFinal[1] = listaFinal[1].strip()
# listaFinal[2] = listaFinal[2].strip()
# listaFinal[3] = listaFinal[3].strip()
# listaFinal[4] = listaFinal[4].strip()

# for item in listaFinal:
#   item = item.strip()
#   print(item)


# contador = 0
# [' Fajita Vegetables', ' Rice', ' Black Beans', ' Cheese', ' Sour Cream']
# for Sergio in listaFinal:
#   print('este es el valor de i:' , Sergio.strip())
#   print('Esta es la posicion de i:(o el contador)', contador)
  # listaFinal[0] = ' Fajita Vegetables'.strip()
#   listaFinal[contador] = Sergio.strip() # listaFinal[i] = listaFinal['Fajita Vegetables']
#   contador +=1 # contador = contador +1

print(listaFinal.index(' Fajita Vegetables'))

# for item in listaFinal:
#   print('Este es el indice', listaFinal.index(item), 'del elemento', item)
#   indice = listaFinal.index(item)
#   listaFinal[indice] = item.strip()
#   listaFinal[listaFinal.index(item)] = item.strip() # demasiado texto en una linea

print(range(0, len(listaFinal)))

# listaFinal[4] = listaFinal[4].strip()
# Variamos el indice de forma dinámica
# for indice in range(0, len(listaFinal)):
#   print(indice)
#   listaFinal[indice] = listaFinal[indice].strip()
# listaFinal[4] = listaFinal[4].strip()

# 
# for index, item in enumerate(listaFinal):
#   print('item', item)
#   print('index', index)
#   listaFinal[index] = item.strip() # listaFinal['Fajita Vegetables']
#  listaFinal[index] = listaFinal[index].strip() # otra opción



#range(0, len(listaFinal))

print('imprimo lista modificada ahora', listaFinal)



# List Comprehension (manejar bien los bucles primero!!!!)
listaFinalLC = [item.strip() for item in listaFinal]
print('LC', listaFinalLC)

# %%
for index, item in enumerate(listaFinal):
  print(index, item)

# %%
listaFinal = [' Fajita Vegetables  ', '    Rice', '   Black Beans', ' Cheese', ' Sour Cream']

for item in listaFinal:
  print('Este es el indice', listaFinal.index(item), 'del elemento', item)
#   indice = listaFinal.index(item)
#   listaFinal[indice] = item.strip()
  listaFinal[listaFinal.index(item)] = item.strip() 

print(listaFinal)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Duda: qué pasa aquí arriba

# %%
#Simulación de fichero con muchas lineas... (Código Eyra)
rawData1 = "6, 1, Chicken Crispy Tacos,[R0asted ChLLI C0rn Salsa, [Fajita Vegetables; Rice; Black Beans; Cheese; Sour Cream]], $8.75"
rawData2 = "14, 1, Carnitas Burrito,[[Tomatillo-Green Chili Salsa (Medium), [Black Beans; Rice; Sour Cream; Lettuce]], $8.99"

lista1 = [rawData1 , rawData2, rawData1 , rawData2, rawData1 , rawData2, rawData1 , rawData2,rawData1 , rawData2,rawData1 , rawData2]

for rawData in lista1:
  rawDataMod = rawData.lower()#convierto la cadena a minusculas
  rawDataMod= rawDataMod.split(",") #separo los elementos de cadena a lista
  rawDataMod[3]=rawDataMod[3].replace("[","") #reemplazo los "["
  rawDataMod[3]=rawDataMod[3].replace("0","o") #reemplazo los "0" por "o"
  rawDataMod[3]=rawDataMod[3].replace("ll","ill") #reemplazo los "ll" por "il"
  rawDataMod[4]=len(rawDataMod[4].split(";"))#sepraro por ";" el tercer elem y tomo su tamaño
  rawDataMod[5]=float(rawDataMod[5].replace("$",""))#reemplazo los "$" por "" en el cuarto elemento
  print(rawData)
  print(rawDataMod)

# %% [markdown]
# ## Ejercicio listas

# %%
notas_a = [1,2,3]
# notas_a[0] +notas_b[0]
notas_b = [6,5,4]
suma_ab = [7,7,7]
media_ab = '¿?'
# a+b --> [1,2,3,6,5,4]
print(notas_a+notas_b)
# a+b --> [ [1,2,3], [6,5,4]]
print([notas_a]+[notas_b])
# a+b --> [7,7,7]

# %%
# Mario-La
notas_a = [1,2,3]
notas_b = [4,5,6]

primera_nota = notas_a[0]+notas_b[0]
segunda_nota = notas_a[1]+notas_b[1]
tercera_nota = notas_a[2]+notas_b[2]

var = [primera_nota,segunda_nota,tercera_nota]

print(var)
print(primera_nota,segunda_nota,tercera_nota)

# %%
# Ona
a = [1,2,3]
b = [6,5,4]
c = [a[0]+b[0] , a[1]+b[1] , a[2]+b[2]]
# c = [((a[0])+(b[0])),((a[1])+(b[1])),((a[2])+(b[2]))]
print('Una lista concatenada', (a+b))
#media:

print('Dos listas en una lista', [a]+[b])

print('la suma de las notas por posicion, las primeras sumadas, segundas, terceras notas', c)

print('primeras notas', (a[0]),(b[0]), '=', (a[0])+(b[0]))
print('segundas notas', (a[1]),(b[1]), '=', (a[1])+(b[1]))
print('terceras notas', (a[2]),(b[2]), '=', (a[2])+(b[2]))

# %%
len([a])
[a][0]
print([a])
print([a]+[b])
print(a+b)

# %%
# Steven
notas_a = [8,3,7]
notas_b = [1,1,6]

media = [notas_a[0] + notas_b[0], notas_a[1] + notas_b[1], notas_a[2] + notas_b[2]]
media = [media[0]/2, media[1]/2, media[2]/2]
media_general = [media[0] + media[1] + media[2]]
media_general = [media_general[0]/3]

print("la media de las notas es ", media, "OwO")
print("la media general de tus notas es ", media_general)

if media_general [0] >=5 : print("has aprobado, mu bien")
else: print("no has aprobado, haber estudiao crack")

# %%
# Luka
notas_a = [1,2,3]
notas_b = [6,5,4]

nota_0 = notas_a[0] + notas_b[0]
nota_1 = notas_a[1] + notas_b[1]
nota_2 = notas_a[2] + notas_b[2]

print(nota_0, nota_1, nota_2)

[nota_0/2, nota_1/2, nota_2/2]

# %%
# Fernando
a = [1, 2, 3]
b = [5, 5, 5]
media = []


media_alumnos = [(a[0]+b[0])/2, 
                 (a[1]+b[1])/2, 
                 (a[2]+b[2])/2]

print('media_alumnos', media_alumnos)
# media []
for x in range(0,3):
    k = (a[x] + b[x])/2 # k = (a[0]+b[0])/2
    print(k)# k = 3.0
    media.append(k) #[].append(3.0) --> media = [3.0]

print(media)

# %%
for i in range(0,3):
  print(i)

# %%
var = notas_a + notas_b
print(var)
sum(notas_a + notas_b)

# %%
a = [1, 2, 3]
b = (5, 5, 5)
print(a)
print(a.extend((5, 5,vbdfgdfb 5)))

# %%
a1 = notas_a[0] + notas_b[0]
a2 = notas_a[1] + notas_b[1]
a3 = notas_a[2] + notas_b[2]

notas_ab = [a1, a2, a3]
print(notas_ab)

# %% [markdown]
# ### Spoiler

# %%
print(len(notas_a), len(notas_b))
notas_ab = []
media_ab = []

notas_a = lista_a
for i in range(0, len(notas_a)):
  print('indice', i)
  print(notas_a[i]+notas_b[i])
  notas_ab.append(notas_a[i]+notas_b[i])
  media_ab.append((notas_a[i]+notas_b[i])/2)

print(notas_ab)
print(media_ab)

# %%
lista = [0,3,4,5,6]
a = lista.remove(3)
print(lista)
b = lista.pop(1)

print(lista, a, b)

# %%
lista = [0,3,4,[5,6]]
#lista.remove(6)
lista[0] = 1
lista[-1].remove(6)

print(lista)

# %%
# Explicación de la diferencia entre funciones que devuelven alguna variable y las que no devuelven nada (None)
def suma(a,b):
  print('sumando...')
  res = a+b
  print('el resultado es', res)
  return res

a = suma(12,34)
print('a', a)

def suma2(a,b):
  print('sumando2...')
  res = a+b
  print('el resultado es', res)

a2 = suma2(12,34)

print('a2', a2)

# %%
dicc = {'Juan': 5.0, 'Jose':7.4}
dicc2 = {'Jose': 7.4, 'Juan':5.0}

dicc['Juan']
dicc2['Juan']

# %% [markdown]
# ## Apuntes

# %% [markdown]
# ### Apuntes de funciones especificas de listas(vistas en pdf)

# %%
lista = ['hola', 'adios', 23,45]
lista.append(89)
print(lista)

lista.insert(1,['holi', 0])
print(lista)

lista.extend(['holi', 0])
print(lista)

# %%
lista = ['hola luis', 'adios juan', 45, 45]
lista.index(45)

# %%
lista = [0,3,4,5,3]


numRem = lista.remove(3)  
print(lista)
numPop = lista.pop(1)

print(lista, numPop, numRem)

# %%
import random

elem = ['Andreas', 'Karen', 'Bea', 'Mariajo', 'Jesús', 
        'Sheyla', 'Carlos', 'Tomás', 'Sergio', 'Adrián']

print(random.choice(elem))

alumno = random.choice(elem)
print(alumno)
pos = elem.index(alumno)
print(pos)
elem.remove(alumno)

aaa = elem.pop(pos)

print(elem)
print(aaa)

# %% [markdown]
# ### Modificar una lista en una sola línea, devolviendo un alumno

# %%
import random
elem = ['Sergio A','Sergio R','Alejandro',
        'Pedro','Andrea','Carlos', 'Álvaro']


        
aaa = elem.pop(elem.index(random.choice(elem)))

print(elem)
print(aaa)
